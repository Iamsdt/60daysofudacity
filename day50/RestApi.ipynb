# %%
from flask import Flask

# %%
app = Flask(__name__)

# %%
@app.route('/')
def main():
    return "Hello"

# %%
from flask import jsonify

@app.route('/<key>/<num>')
def second(key, num):
    list = {'output': "Hello  " +str(num) + str(key) }
    return jsonify(results = list)

# %%
if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Aug/2019 16:10:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Aug/2019 16:10:41] "GET /data/10 HTTP/1.1" 200 -

# %%
import base64

# %%
img = open('0.png', 'rb').read()

# %%
type(img)
# Out:
# bytes

# %%
encode = base64.encodebytes(img)

# %%
s = base64.decodestring(encode)
# Out:
# /home/shudipto/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: decodestring() is a deprecated alias since Python 3.1, use decodebytes()
#   """Entry point for launching an IPython kernel.

# %%
s[:10]
# Out:
# b'\x89PNG\r\n\x1a\n\x00\x00'

# %%
with open("output.png", "wb") as fh:
    fh.write(base64.decodebytes(encode))

# %%
from PIL import Image
Image.open('output.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x900 at 0x7F578C1246D8>

# %%
import numpy as np
arr = Image.open('0.png')

# %%
img = np.array(arr)

# %%
img.shape
# Out:
# (900, 600, 3)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.1.0'

# %%
img = open('out.png', 'rb').read()

# %%
encode = base64.encodebytes(img)

# %%
with open("output.png", "wb") as fh:
    fh.write(base64.decodebytes(encode))

# %%
from PIL import Image
Image.open('output.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x900 at 0x7F576F8DF048>

# %%
s = "\n"

# %%
encode = str.encode(s)

# %%
type(encode)
# Out:
# bytes

# %%
import base64
with open("output.png", "wb") as fh:
    fh.write(base64.decodebytes(encode))

# %%
from PIL import Image
Image.open('output.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=306x306 at 0x7F8B4D9DFFD0>

# %%
import requests

response = requests.get('http://0.0.0.0:5000/01732033963/16')
data = response.json()

# %%
encode = str.encode(data['output'])

# %%
import base64
with open("output2.png", "wb") as fh:
    fh.write(base64.decodebytes(encode))

# %%
from PIL import Image
Image.open('output2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=306x306 at 0x7F8B4CED2828>

# %%
import requests
import base64
from PIL import Image

response = requests.get('https://anime-generator.herokuapp.com/01732033963/16')
data = response.json()
encode = str.encode(data['output'])

with open("output3.png", "wb") as fh:
    fh.write(base64.decodebytes(encode))

Image.open('output3.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=306x306 at 0x7F83A027CDD8>
